# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('C:\\Users\\Harshit Reddy\\Downloads\\Customer_retention_dataset--1-\\Customer_retention_dataset\\customer_retention_dataset.xlsx')
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # EDA

# %%
sns.countplot(df['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(df['3 Which city do you shop online from?'])
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?', ylabel='count'>

# %%
plt.figure(figsize=(13,5))
sns.countplot(df['6 How many times you have made an online purchase in the past 1 year?'])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %%
plt.figure(figsize=(10,4))
sns.countplot(df['7 How do you access the internet while shopping on-line?'])
# Out:
# <AxesSubplot:xlabel='7 How do you access the internet while shopping on-line?', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['8 Which device do you use to access the online shopping?'])
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["9 What is the screen size of your mobile device?						                                        "])
# Out:
# <AxesSubplot:xlabel='9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["10 What is the operating system (OS) of your device?				                                          "])
# Out:
# <AxesSubplot:xlabel='10 What is the operating system (OS) of your device?\t\t\t\t                                          ', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["11 What browser do you run on your device to access the website?			                                                          "])
# Out:
# <AxesSubplot:xlabel='11 What browser do you run on your device to access the website?\t\t\t                                                          ', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '])
# Out:
# <AxesSubplot:xlabel='12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["13 After first visit, how do you reach the online retail store?				                                                   "])
# Out:
# <AxesSubplot:xlabel='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '])
# Out:
# <AxesSubplot:xlabel='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["15 What is your preferred payment Option?					                                                                                                                               "])
# Out:
# <AxesSubplot:xlabel='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ', ylabel='count'>

# %%
plt.figure(figsize=(13,5))
sns.countplot(df["17 Why did you abandon the “Bag”, “Shopping Cart”?					                                                                                                                                                       "])
# Out:
# <AxesSubplot:xlabel='17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ', ylabel='count'>

# %%
df["17 Why did you abandon the “Bag”, “Shopping Cart”?					                                                                                                                                                       "].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['18 The content on the website must be easy to read and understand'])
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %% [markdown]
# From the above observations, we can say that

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['19 Information on similar product to the one highlighted  is important for product comparison'])
# Out:
# <AxesSubplot:xlabel='19 Information on similar product to the one highlighted  is important for product comparison', ylabel='count'>

# %% [markdown]
# From the above observations, we can say that

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['22 Ease of navigation in website'])
# Out:
# <AxesSubplot:xlabel='22 Ease of navigation in website', ylabel='count'>

# %% [markdown]
# From the above observations, we can say that

# %%
plt.figure(figsize=(10,5))
sns.countplot(df['23 Loading and processing speed'])
# Out:
# <AxesSubplot:xlabel='23 Loading and processing speed', ylabel='count'>

# %%
sns.stripplot(x='1Gender of respondent', y='5 Since How Long You are Shopping Online ?',data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='5 Since How Long You are Shopping Online ?'>

# %%
sns.swarmplot(x='1Gender of respondent', y='8 Which device do you use to access the online shopping?',data=df)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='8 Which device do you use to access the online shopping?'>

# %%
obj_list = df.select_dtypes(include = "object").columns
obj_list

# converting all categorical columns into numerical data

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for feature in obj_list:
    df[feature] = le.fit_transform(df[feature].astype(str))

# %%
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        1                    1
# 1                        0                    0
# 2                        0                    0
# 3                        1                    0
# 4                        0                    0
# ..                     ...                  ...
# 264                      0                    0
# 265                      0                    1
# 266                      0                    2
# 267                      0                    4
# 268                      0                    2
#
#      3 Which city do you shop online from?  \
# 0                                        2
# 1                                        2
# 2                                        4
# 3                                        6
# 4                                        0
# ..                                     ...
# 264                                     10
# ...

# %%
k=['1Gender of respondent','2 How old are you? ','3 Which city do you shop online from?',
   '4 What is the Pin Code of where you shop online from?']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['5 Since How Long You are Shopping Online ?','6 How many times you have made an online purchase in the past 1 year?',
   '7 How do you access the internet while shopping on-line?','8 Which device do you use to access the online shopping?']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=["9 What is the screen size of your mobile device?						                                        ",
  "10 What is the operating system (OS) of your device?				                                          ",
  "11 What browser do you run on your device to access the website?			                                                          ",
  '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ']
j=1
plt.figure(figsize=(20,13))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=["13 After first visit, how do you reach the online retail store?				                                                   ",
  '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',
  "15 What is your preferred payment Option?					                                                                                                                               ",
   ]
j=1
plt.figure(figsize=(20,13))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=["17 Why did you abandon the “Bag”, “Shopping Cart”?					                                                                                                                                                       ",
  '18 The content on the website must be easy to read and understand',
  '19 Information on similar product to the one highlighted  is important for product comparison',
  '20 Complete information on listed seller and product being offered is important for purchase decision.']
j=1
plt.figure(figsize=(20,10))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['21 All relevant information on listed products must be stated clearly',
  '22 Ease of navigation in website','23 Loading and processing speed','24 User friendly Interface of the website']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['25 Convenient Payment methods','26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
  '27 Empathy (readiness to assist with queries) towards the customers','28 Being able to guarantee the privacy of the customer']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
  '30 Online shopping gives monetary benefit and discounts','31 Enjoyment is derived from shopping online',
  '32 Shopping online is convenient and flexible']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['33 Return and replacement policy of the e-tailer is important for purchase decision',
  '34 Gaining access to loyalty programs is a benefit of shopping online',
  '35 Displaying quality Information on the website improves satisfaction of customers',
  '36 User derive satisfaction while shopping on a good quality website or application']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['37 Net Benefit derived from shopping online can lead to users satisfaction',
  '38 User satisfaction cannot exist without trust',
  '39 Offering a wide variety of listed product in several category','40 Provision of complete and relevant product information']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['41 Monetary savings','42 The Convenience of patronizing the online retailer',
  '43 Shopping on the website gives you the sense of adventure',
  '44 Shopping on your preferred e-tailer enhances your social status']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['45 You feel gratification shopping on your favorite e-tailer',
  '46 Shopping on the website helps you fulfill certain roles','47 Getting value for money spent',
  'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Easy to use website or application','Visual appealing web-page layout','Wild variety of product on offer',
  'Complete, relevant description information of products']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Fast loading website speed of website and application','Reliability of the website or application',
  'Quickness to complete purchase','Availability of several payment options']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Speedy order delivery ','Privacy of customers’ information',
  'Security of customer financial information','Perceived Trustworthiness']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Presence of online assistance through multi-channel','Longer time to get logged in (promotion, sales period)',
  'Longer time in displaying graphics and photos (promotion, sales period)',
  'Late declaration of price (promotion, sales period)']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Longer page loading time (promotion, sales period)',
  'Limited mode of payment on most products (promotion, sales period)',
  'Longer delivery period','Change in website/Application design']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Frequent disruption when moving from one page to another',
  'Website is as efficient as before',
  'Which of the Indian online retailer would you recommend to a friend?']
j=1
plt.figure(figsize=(15,7))
for i in k:
    plt.subplot(2,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['1Gender of respondent','2 How old are you? ','3 Which city do you shop online from?',
   '4 What is the Pin Code of where you shop online from?']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['5 Since How Long You are Shopping Online ?','6 How many times you have made an online purchase in the past 1 year?',
   '7 How do you access the internet while shopping on-line?','8 Which device do you use to access the online shopping?']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=["9 What is the screen size of your mobile device?						                                        ",
  "10 What is the operating system (OS) of your device?				                                          ",
  "11 What browser do you run on your device to access the website?			                                                          ",
  '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ']
j=1
plt.figure(figsize=(16,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=["13 After first visit, how do you reach the online retail store?				                                                   ",
  '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',
  "15 What is your preferred payment Option?					                                                                                                                               ",
]
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(3,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=["17 Why did you abandon the “Bag”, “Shopping Cart”?					                                                                                                                                                       ",
  '18 The content on the website must be easy to read and understand',
  '19 Information on similar product to the one highlighted  is important for product comparison',
  '20 Complete information on listed seller and product being offered is important for purchase decision.']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['21 All relevant information on listed products must be stated clearly',
  '22 Ease of navigation in website','23 Loading and processing speed','24 User friendly Interface of the website']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['25 Convenient Payment methods','26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
  '27 Empathy (readiness to assist with queries) towards the customers','28 Being able to guarantee the privacy of the customer']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
  '30 Online shopping gives monetary benefit and discounts','31 Enjoyment is derived from shopping online',
  '32 Shopping online is convenient and flexible']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['33 Return and replacement policy of the e-tailer is important for purchase decision',
  '34 Gaining access to loyalty programs is a benefit of shopping online',
  '35 Displaying quality Information on the website improves satisfaction of customers',
  '36 User derive satisfaction while shopping on a good quality website or application']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['37 Net Benefit derived from shopping online can lead to users satisfaction',
  '38 User satisfaction cannot exist without trust',
  '39 Offering a wide variety of listed product in several category','40 Provision of complete and relevant product information']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['41 Monetary savings','42 The Convenience of patronizing the online retailer',
  '43 Shopping on the website gives you the sense of adventure',
  '44 Shopping on your preferred e-tailer enhances your social status']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['45 You feel gratification shopping on your favorite e-tailer',
  '46 Shopping on the website helps you fulfill certain roles','47 Getting value for money spent',
  'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Easy to use website or application','Visual appealing web-page layout','Wild variety of product on offer',
  'Complete, relevant description information of products']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Fast loading website speed of website and application','Reliability of the website or application',
  'Quickness to complete purchase','Availability of several payment options']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Speedy order delivery ','Privacy of customers’ information',
  'Security of customer financial information','Perceived Trustworthiness']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Presence of online assistance through multi-channel','Longer time to get logged in (promotion, sales period)',
  'Longer time in displaying graphics and photos (promotion, sales period)',
  'Late declaration of price (promotion, sales period)']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Longer page loading time (promotion, sales period)',
  'Limited mode of payment on most products (promotion, sales period)',
  'Longer delivery period','Change in website/Application design']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Frequent disruption when moving from one page to another',
  'Website is as efficient as before',
  'Which of the Indian online retailer would you recommend to a friend?']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['1Gender of respondent','2 How old are you? ','3 Which city do you shop online from?',
   '4 What is the Pin Code of where you shop online from?']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['5 Since How Long You are Shopping Online ?','6 How many times you have made an online purchase in the past 1 year?',
   '7 How do you access the internet while shopping on-line?','8 Which device do you use to access the online shopping?']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(2,2,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=["9 What is the screen size of your mobile device?						                                        ",
  "10 What is the operating system (OS) of your device?				                                          ",
  "11 What browser do you run on your device to access the website?			                                                          ",
  '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ']
j=1
plt.figure(figsize=(16,10))
for i in k:
    plt.subplot(2,2,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=["13 After first visit, how do you reach the online retail store?				                                                   ",
  '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',
  "15 What is your preferred payment Option?					                                                                                                                               ",
]
j=1
plt.figure(figsize=(16,10))
for i in k:
    plt.subplot(2,2,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=["17 Why did you abandon the “Bag”, “Shopping Cart”?					                                                                                                                                                       ",
  '18 The content on the website must be easy to read and understand',
  '19 Information on similar product to the one highlighted  is important for product comparison',
  '20 Complete information on listed seller and product being offered is important for purchase decision.']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['21 All relevant information on listed products must be stated clearly',
  '22 Ease of navigation in website','23 Loading and processing speed','24 User friendly Interface of the website']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(2,2,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['25 Convenient Payment methods','26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
  '27 Empathy (readiness to assist with queries) towards the customers','28 Being able to guarantee the privacy of the customer']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
  '30 Online shopping gives monetary benefit and discounts','31 Enjoyment is derived from shopping online',
  '32 Shopping online is convenient and flexible']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['33 Return and replacement policy of the e-tailer is important for purchase decision',
  '34 Gaining access to loyalty programs is a benefit of shopping online',
  '35 Displaying quality Information on the website improves satisfaction of customers',
  '36 User derive satisfaction while shopping on a good quality website or application']
j=1
plt.figure(figsize=(15,10))
for i in k:
    plt.subplot(4,1,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['37 Net Benefit derived from shopping online can lead to users satisfaction',
  '38 User satisfaction cannot exist without trust',
  '39 Offering a wide variety of listed product in several category','40 Provision of complete and relevant product information']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['41 Monetary savings','42 The Convenience of patronizing the online retailer',
  '43 Shopping on the website gives you the sense of adventure',
  '44 Shopping on your preferred e-tailer enhances your social status']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['45 You feel gratification shopping on your favorite e-tailer',
  '46 Shopping on the website helps you fulfill certain roles','47 Getting value for money spent',
  'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Easy to use website or application','Visual appealing web-page layout','Wild variety of product on offer',
  'Complete, relevant description information of products']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Fast loading website speed of website and application','Reliability of the website or application',
  'Quickness to complete purchase','Availability of several payment options']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Speedy order delivery ','Privacy of customers’ information',
  'Security of customer financial information','Perceived Trustworthiness']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Presence of online assistance through multi-channel','Longer time to get logged in (promotion, sales period)',
  'Longer time in displaying graphics and photos (promotion, sales period)',
  'Late declaration of price (promotion, sales period)']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Longer page loading time (promotion, sales period)',
  'Limited mode of payment on most products (promotion, sales period)',
  'Longer delivery period','Change in website/Application design']
j=1
plt.figure(figsize=(17,10))
for i in k:
    plt.subplot(4,1,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %%
k=['Frequent disruption when moving from one page to another',
  'Website is as efficient as before',
  'Which of the Indian online retailer would you recommend to a friend?']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(2,2,j)
    sns.histplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()
